# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pwd
# Out:
# /content

# %%
# %cd /content/drive/My Drive/copy-brain
# Out:
# /content/drive/My Drive/copy-brain

# %%
# !pwd
# Out:
# /content/drive/My Drive/copy-brain

# %%
# !ls
# Out:
# 'data-cleaning (1).ipynb'   rumi-gpt2
#  data-cleaning.ipynb	    run_generation.py
#  Dataset.txt		   'run_language_modeling (1).py'
# 'GPT2 (1).ipynb'	    run_language_modeling.py
#  GPT2.ipynb		    runs

# %%
import pandas as pd

# %%
with open("Dataset.txt") as file:
    data = file.readlines()

# %%
len(data)
# Out:
# 822

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
from sklearn.model_selection import train_test_split

# %%
train = data[:int(len(data)*0.90)]

# %%
test = data[int(len(data)*0.90):]

# %%
with open("train.txt", "w") as file:
    file.writelines(train)

# %%
with open("val.txt", "w") as file:
    file.writelines(test)
